# %% [markdown]
# #Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture

# !pip install transformers datasets evaluate
# !pip install --upgrade accelerate

# %%
from datasets import DatasetDict, Dataset, load_dataset, load_metric
import numpy as np
import pandas as pd
import torch
from tqdm import tqdm

# %% [markdown]
# #Instantiate model

# %%
from transformers import AutoModelForMultipleChoice, AutoTokenizer, TrainingArguments, Trainer
model_checkpoint = "bert-base-uncased"
model = AutoModelForMultipleChoice.from_pretrained(model_checkpoint)

batch_size = 16
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForMultipleChoice were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, use_fast=True)
# Out:
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %% [markdown]
# #Load and Preprocess data

# %%
data = np.load('/content/drive/MyDrive/brain_teaser/datasets/WP-train.npy', allow_pickle=True)

# %%
data_dict = {'id':[],
             'question':[],
             'answer':[],
             'distractor1':[],
             'distractor2':[],
             'distractor(unsure)':[],
             'label':[],
             'choice_list':[],
             'choice_order':[]}
for i in data:
  for k,v in i.items():
    data_dict[k].append(v)

# %%
df = pd.DataFrame(data_dict, columns=['id', 'question', 'answer', 'distractor1', 'distractor2', 'distractor(unsure)', 'label', 'choice_list', 'choice_order'])
df = df.drop(columns=['distractor1','distractor2', 'distractor(unsure)'])
df
# Out:
#             id                                           question  \
# 0         WP-0          How do you spell COW in thirteen letters?
# 1      WP-0_SR         In thirteen letters, how do you spell COW?
# 2      WP-0_CR             How do you spell COB in seven letters?
# 3         WP-1  If eleven plus two equals one, what does nine ...
# 4      WP-1_SR  What does nine plus five equal if eleven plus ...
# ..         ...                                                ...
# 391  WP-162_SR                   Which sort of bell doesn't ring?
# 392  WP-162_CR   What kind of "stone" can't be found in a quarry?
# 393     WP-163                      What type of ice never melts?
# 394  WP-163_SR                     What kind of ice doesn't melt?
# 395  WP-163_CR            What kind of ice doesn't contain water?
#
#                 answer  label  \
# 0    SEE O DOUBLE YOU.      1
# 1    SEE O DOUBLE YOU.      2
# 2            SEE O BEE      2
# 3                 Two.      1
# 4                 Two.      1
# ..                 ...    ...
# 391        A dumbbell.      0
# 392         Milestone.      2
# 393              Dice.      0
# 394              Dice.      1
# 395           Dry ice.      1
#
#                                            choice_list  choice_order
# 0    [SEE OH DEREFORD, SEE O DOUBLE YOU., COWCOWCOW...  [2, 0, 1, 3]
# 1    [SEE OH DEREFORD, COWCOWCOWCOWW, SEE O DOUBLE ...  [2, 1, 0, 3]
# 2        [COBCOBB, COBBLER, SEE O BEE, None of above.]  [1, 2, 0, 3]
# 3                [Four., Two., Three., None of above.]  [2, 0, 1, 3]
# 4                [Three., Two., Four., None of above.]  [1, 0, 2, 3]
# ..                                                 ...           ...
# 391  [A dumbbell., A doorbell., A cowbell., None of...  [0, 1, 2, 3]
# 392  [Cobblestone., Sandstone., Milestone., None of...  [1, 2, 0, 3]
# 393  [Dice., Flaked ice., Glacier ice., None of abo...  [0, 2, 1, 3]
# 394  [Glacier ice., Dice., Flaked ice., None of abo...  [1, 0, 2, 3]
# 395  [Flaked ice., Dry ice., Glacier ice., None of ...  [1, 0, 2, 3]
#
# [396 rows x 6 columns]

# %%
df = df.sample(frac=1, random_state=42).reset_index(drop=True)
dataset = Dataset.from_pandas(df)

# %%
def show_one(example):
    print(f"Question: {example['question']}")
    print(f"  A - {example['choice_list'][0].strip()}")
    print(f"  B - {example['choice_list'][1].strip()}")
    print(f"  C - {example['choice_list'][2].strip()}")
    print(f"  D - {example['choice_list'][3].strip()}")
    print(f"\nGround truth: option {['A', 'B', 'C', 'D'][example['label']]}")

# %%
show_one(dataset[0])
# Out:
# Question: What bird is very rude?
#   A - Humming bird.
#   B - Eagle.
#   C - Mocking bird.
#   D - None of above.
#
# Ground truth: option C

# %%
def preprocess_function(example):
  question = [[q] * 4 for q in example['question']]
  choice = [example['choice_list'][i] for i in range(len(question))]

  question = sum(question, [])
  choice = sum(choice, [])
  print(question, len(question))
  print(choice, len(choice))
  tokenized_example = tokenizer(question, choice, truncation=True)
  return {k: [v[i : i + 4] for i in range(0, len(v), 4)] for k, v in tokenized_example.items()}

# %%
examples = dataset[:5]
features = preprocess_function(examples)
print(len(features["input_ids"]), len(features["input_ids"][0]), [len(x) for x in features["input_ids"][0]])
# Out:
# ['What bird is very rude?', 'What bird is very rude?', 'What bird is very rude?', 'What bird is very rude?', 'What type of currency do vampires use?', 'What type of currency do vampires use?', 'What type of currency do vampires use?', 'What type of currency do vampires use?', 'Guess next letters in the series GNL.', 'Guess next letters in the series GNL.', 'Guess next letters in the series GNL.', 'Guess next letters in the series GNL.', 'What is at the end of a cow and in front of a woman?', 'What is at the end of a cow and in front of a woman?', 'What is at the end of a cow and in front of a woman?', 'What is at the end of a cow and in front of a woman?', "Which sort of bell doesn't ring?", "Which sort of bell doesn't ring?", "Which sort of bell doesn't ring?", "Which sort of bell doesn't ring?"] 20
# ['Humming bird.', 'Eagle.', 'Mocking bird.', 'None of above.', 'New money.', 'Blood money.', 'Old money.', 'None of above.', 'T,M,G.', 'I, T, S.\n', 'T,N,T.', 'None of above.', 'The letter O.', 'The letter N.', 'The letter W.', 'None of above.', 'A dumbbell.', 'A doorbell.', 'A cowbell.', 'None of above.'] 20
# 5 4 [12, 11, 12, 13]

# %%
encoded_dataset = dataset.map(preprocess_function, batched=True)
dataset_train_test = encoded_dataset.train_test_split(test_size=0.1, seed=42)
# Out:
# Map:   0%|          | 0/396 [00:00<?, ? examples/s]
# ['What bird is very rude?', 'What bird is very rude?', 'What bird is very rude?', 'What bird is very rude?', 'What type of currency do vampires use?', 'What type of currency do vampires use?', 'What type of currency do vampires use?', 'What type of currency do vampires use?', 'Guess next letters in the series GNL.', 'Guess next letters in the series GNL.', 'Guess next letters in the series GNL.', 'Guess next letters in the series GNL.', 'What is at the end of a cow and in front of a woman?', 'What is at the end of a cow and in front of a woman?', 'What is at the end of a cow and in front of a woman?', 'What is at the end of a cow and in front of a woman?', "Which sort of bell doesn't ring?", "Which sort of bell doesn't ring?", "Which sort of bell doesn't ring?", "Which sort of bell doesn't ring?", 'How did the champ repair the leaking facet?', 'How did the champ repair the leaking facet?', 'How did the champ repair the leaking facet?', 'How did the champ repair the leaking facet?', 'What dress does everyone have, but no one wears?', 'What dress does everyone have, but no one wears?', 'What dress does everyone have, but no one wears?', 'What dress does everyone have, but no one wears?', 'What type of pot never boils?', 'What type of pot never boils?', 'What type of pot never boils?', 'What type of pot never boils?', 'Mrs. Three lives in a Triangle, Mrs. Four lives in a Quadrilateral, who lives in the Pentagon? ', 'Mrs. Three lives in a Triangle, Mrs. Four lives in a Quadrilateral, who lives in the Pentagon? ', 'Mrs. Three lives in a Triangle, Mrs. Four lives in a Quadrilateral, who lives in the Pentagon? ', 'Mrs. Three lives in a Triangle, Mrs. Four lives in a Quadrilateral, who lives in the Pentagon? ', 'What type of dog sits in the sun all day?', 'What type of dog sits in the sun all day?', 'What type of dog sits in the sun all day?', 'What type of dog sits in the sun all day?', 'Tomorrow I am surely here, yesterday I am found as well. Today I am gone. Who am I?', 'Tomorrow I am surely here, yesterday I am found as well. Today I am gone. Who am I?', 'Tomorrow I am surely here, yesterday I am found as well. Today I am gone. Who am I?', 'Tomorrow I am surely here, yesterday I am found as well. Today I am gone. Who am I?', 'What sort of cheese is made in reverse?', 'What sort of cheese is made in reverse?', 'What sort of cheese is made in reverse?', 'What sort of cheese is made in reverse?', "What is a computer's preferred treat?", "What is a computer's preferred treat?", "What is a computer's preferred treat?", "What is a computer's preferred treat?", 'How do you spell hard water with three letters?', 'How do you spell hard water with three letters?', 'How do you spell hard water with three letters?', 'How do you spell hard water with three letters?', "What kind of bar doesn't offer alcoholic beverages?", "What kind of bar doesn't offer alcoholic beverages?", "What kind of bar doesn't offer alcoholic beverages?", "What kind of bar doesn't offer alcoholic beverages?", 'What sort of note is valuable?', 'What sort of note is valuable?', 'What sort of note is valuable?', 'What sort of note is valuable?', 'Which of the following words is incorrectly in the dictionary?\n', 'Which of the following words is incorrectly in the dictionary?\n', 'Which of the following words is incorrectly in the dictionary?\n', 'Which of the following words is incorrectly in the dictionary?\n', "What kind of ice doesn't melt?", "What kind of ice doesn't melt?", "What kind of ice doesn't melt?", "What kind of ice doesn't melt?", 'What side of church alwasy has more sunshine?', 'What side of church alwasy has more sunshine?', 'What side of church alwasy has more sunshine?', 'What side of church alwasy has more sunshine?', 'Which ham has the best springiness?', 'Which ham has the best springiness?', 'Which ham has the best springiness?', 'Which ham has the best springiness?', 'What is in seasons, seconds, centuries and minutes but not in decades, years or da ...
# ['Humming bird.', 'Eagle.', 'Mocking bird.', 'None of above.', 'New money.', 'Blood money.', 'Old money.', 'None of above.', 'T,M,G.', 'I, T, S.\n', 'T,N,T.', 'None of above.', 'The letter O.', 'The letter N.', 'The letter W.', 'None of above.', 'A dumbbell.', 'A doorbell.', 'A cowbell.', 'None of above.', 'With an adjustable wrench.', 'With a monkey wrench.', 'With a stubby wrench.', 'None of above.', 'Suit.', 'Address.', 'Wedding dress.', 'None of above.', 'Flowerpot.', 'Teapot.', 'Coffee pot.', 'None of above.', 'Mrs. Three.', 'Mr. Five.', 'Mr. Three, Mrs Four and Mrs Five share the house.', 'None of above.', 'Husky.', 'Hotdog.', 'Corgi.', 'None of above.', 'The Letter R.', 'The Letter T.', 'The Letter E.', 'None of above.', 'Cheddar cheese.', 'Edam cheese.', 'Blue cheese.', 'None of above.', 'Cookie.', 'Chips.', 'Candy.', 'None of above.', 'HHO.', 'ICE.', 'HAW.', 'None of above.', 'Hotel bar.', 'Sandbar.', 'Cocktail bar.', 'None of above.', 'A music note.', 'A banknote.', 'A high note.', 'None of above.', 'The word "incorrectly".\n', 'The word "false".', 'The word "wrong".', 'None of above.', 'Glacier ice.', 'Dice.', 'Flaked ice.', 'None of above.', 'Eastside.', 'Westside.', 'Outside.', 'None of above.', 'Sliced ham.', 'Honey ham.', 'Slingsham.', 'None of above.', 'The letter A.', 'The letter D.', 'The letter N.', 'None of above.', 'Cobblestone.', 'Sandstone.', 'Milestone.', 'None of above.', 'Doghouse.', 'Farmhouse.', 'Greenhouse.', 'None of above.', 'SEE OH DEREFORD', 'SEE O DOUBLE YOU.', 'COWCOWCOWCOWW', 'None of above.', "The letter 'M'.", "The letter 'R'.", "The letter 'N'.", 'None of above.', 'Yesterday.', 'Friday.', 'Monday.', 'None of above.', 'Minestrone soup.', 'Alphabet soup.', 'Tomato soup.', 'None of above.', 'Oil, if we rearrange the letters, they form the word "oil". ', 'Water. Hijklmno is "H to O" in the alphabet. Water is H20.', 'Milk. "H L M N O" is similar as the nursery rhyme "High low，maids in a row", which commonly associated with milking cows. ', 'None of above.', 'A checkbox.', 'A pencil box.', 'A cigar box.', 'None of above.', 'Pie.', 'Hot dog.', 'Hamburger.', 'None of above.', 'The letter M.', 'The letter N.', 'The letter E.', 'None of above.', 'Five.', 'Eleven.', 'Seven\n', 'None of above.', 'Nightfall.', 'Waterfall.', 'Freefall.', 'None of above.', 'Carrot root.', 'Cabbage root.', 'Square root.', 'None of above.', 'Academic.', 'Alphabet.', 'Abcdefghijklmnopqrstuvwxyz.', 'None of above.', 'Remove the letter "i".', 'Move the letter "t" to the end.', 'Just flip it.', 'None of above.', 'Gold key.', 'Car key.', 'Monkey.', 'None of above.', 'Eat alphabet soup.', 'Eat minestrone soup.', 'Eat tomato soup.', 'None of above.', 'A worker ant(ergate).', 'An antique.', 'A queen ant.', 'None of above.', 'California.', 'Florida.', 'Mississippi.', 'None of above.', 'An antique.', 'A worker ant(ergate).', 'A queen ant.', 'None of above.', 'Catfish.', 'Tuna.', 'Surgeonfish.', 'None of above.', 'G.', 'H.', 'T.', 'None of above.', 'Because we are talking the computer.', 'Because we are talking the price.', 'Because we are talking the time.', 'None of above.', 'The letter E.', 'The letter T.', 'The letter G.', 'None of above.', 'Remove G,I and R and add A,D and Y.', 'Add N,O and T at beginning.', 'Add B,O and Y at beginning.', 'None of above.', 'Those that at the end of alphabet.', 'Those that at the middle of alphabet.', 'Those that come after T.', 'None of above.', 'Scholarship', 'Battleship.', 'Spaceship.', 'None of above.', "Take away the 'p'.", "Take away the 'e'.", "Take away the 'i'.", 'None of above.', 'Add the letter B.', 'Add the letter F.', 'Add the letter L.', 'None of above.', 'Abbreviation.', 'Truncation.', 'Short.', 'None of above.', 'The letter I.', 'The letter E.', 'The letter T.', 'None of above.', 'Ben is buying English word cards. The price is determined by the number of letters in the spelled-out number.', 'Ben is buying English word cards. The price is determined by the number of vowels in the  ...

# %%
idx = 0
[tokenizer.decode(encoded_dataset["input_ids"][idx][i]) for i in range(4)]
# Out:
# ['[CLS] what bird is very rude? [SEP] humming bird. [SEP]',
#  '[CLS] what bird is very rude? [SEP] eagle. [SEP]',
#  '[CLS] what bird is very rude? [SEP] mocking bird. [SEP]',
#  '[CLS] what bird is very rude? [SEP] none of above. [SEP]']

# %%
dataset_train_test
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'question', 'answer', 'label', 'choice_list', 'choice_order', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 356
#     })
#     test: Dataset({
#         features: ['id', 'question', 'answer', 'label', 'choice_list', 'choice_order', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 40
#     })
# })

# %% [markdown]
# #Train Models

# %%
from dataclasses import dataclass
from transformers.tokenization_utils_base import PreTrainedTokenizerBase, PaddingStrategy
from typing import Optional, Union

@dataclass
class DataCollatorForMultipleChoice:
    """
    Data collator that will dynamically pad the inputs for multiple choice received.
    """

    tokenizer: PreTrainedTokenizerBase
    padding: Union[bool, str, PaddingStrategy] = True
    max_length: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None

    def __call__(self, features):
        label_name = "label" if "label" in features[0].keys() else "labels"
        labels = [feature.pop(label_name) for feature in features]
        batch_size = len(features)
        num_choices = len(features[0]["input_ids"])
        flattened_features = [[{k: v[i] for k, v in feature.items()} for i in range(num_choices)] for feature in features]
        flattened_features = sum(flattened_features, [])

        batch = self.tokenizer.pad(
            flattened_features,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors="pt",
        )

        # Un-flatten
        batch = {k: v.view(batch_size, num_choices, -1) for k, v in batch.items()}
        # Add back labels
        batch["labels"] = torch.tensor(labels, dtype=torch.int64)
        return batch

# %%
accepted_keys = ["input_ids", "attention_mask", "label"]
features = [{k: v for k, v in dataset_train_test["train"][i].items() if k in accepted_keys} for i in range(10)]
batch = DataCollatorForMultipleChoice(tokenizer)(features)
# Out:
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.

# %%
[tokenizer.decode(batch["input_ids"][8][i].tolist()) for i in range(4)]
# Out:
# ['[CLS] what bird is very rude? [SEP] humming bird. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] what bird is very rude? [SEP] eagle. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] what bird is very rude? [SEP] mocking bird. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] what bird is very rude? [SEP] none of above. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]']

# %%
import numpy as np

def compute_metrics(eval_predictions):
    predictions, label_ids = eval_predictions
    preds = np.argmax(predictions, axis=1)
    return {"accuracy": (preds == label_ids).astype(np.float32).mean().item()}

# %%
model_name = model_checkpoint.split("/")[-1]
args = TrainingArguments(
    output_dir=f"{model_name}-WP-finetuned",
    seed=0,
    evaluation_strategy = "epoch",
    save_strategy = "epoch",
    logging_steps=10,
    learning_rate=1e-4,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=10,
    weight_decay=0.01,
    push_to_hub=False,
    load_best_model_at_end=True,
    save_total_limit=2,
    metric_for_best_model="accuracy",
)

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=dataset_train_test["train"],
    eval_dataset=dataset_train_test["test"],
    tokenizer=tokenizer,
    data_collator=DataCollatorForMultipleChoice(tokenizer),
    compute_metrics=compute_metrics,
)

# %% [markdown]
# ##<font color=yellow>BERT-base</font>

# %% [markdown]
# ###<font color=greeen>word puzzle</font>

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='230' max='230' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [230/230 03:04, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.787947</td>
#       <td>0.675000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.419304</td>
#       <td>0.775000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.314118</td>
#       <td>0.850000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.574959</td>
#       <td>0.825000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>0.585125</td>
#       <td>0.850000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>No log</td>
#       <td>0.688956</td>
#       <td>0.825000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>No log</td>
#       <td>0.685295</td>
#       <td>0.825000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>No log</td>
#       <td>0.738119</td>
#       <td>0.875000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>No log</td>
#       <td>0.682928</td>
#       <td>0.850000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>No log</td>
#       <td>0.704824</td>
#       <td>0.825000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=230, training_loss=0.19897376350734544, metrics={'train_runtime': 185.5141, 'train_samples_per_second': 19.19, 'train_steps_per_second': 1.24, 'total_flos': 427461182498784.0, 'train_loss': 0.19897376350734544, 'epoch': 10.0})

# %%
trainer.save_model("/content/drive/MyDrive/brain_teaser/final_best_models/BERT_base_uncased_word_puzzle")

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='3' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3/3 00:00]
#     </div>
# {'eval_loss': 0.31411826610565186,
#  'eval_accuracy': 0.8500000238418579,
#  'eval_runtime': 0.6505,
#  'eval_samples_per_second': 61.49,
#  'eval_steps_per_second': 4.612,
#  'epoch': 10.0}
